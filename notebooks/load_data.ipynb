# %%
# check if we can connect to the postgres database

import os
import psycopg2

PASSWORD = os.getenv("POSTGRES_PASSWORD")

conn = psycopg2.connect(
    host="localhost",
    database="postgres",
    user="postgres",
    port=15432,
    password=PASSWORD
)

# list all tables in the database
cursor = conn.cursor()
cursor.execute("SELECT table_name FROM information_schema.tables WHERE table_schema='public'")
tables = cursor.fetchall()
print(tables)

# install postgis extension
cursor.execute("CREATE EXTENSION IF NOT EXISTS postgis;")
conn.commit()
# Out:
# [('geography_columns',), ('geometry_columns',), ('spatial_ref_sys',), ('places',)]

# %%
# import pydantic

# class Place(pydantic.BaseModel):
#     names: list[str]
#     geometry: bytearray
#     type: str
#     id: str
#     hierarchy: list[str]
#     properties: dict

# %%
from sqlalchemy import Column, String, Text, JSON, ARRAY
from sqlalchemy.orm import declarative_base
from geoalchemy2 import Geometry

Base = declarative_base()

class PlaceORM(Base):
    __tablename__ = "places"

    id = Column(String, primary_key=True)
    names = Column(ARRAY(Text))
    type = Column(Text)
    hierarchy = Column(ARRAY(Text))
    geometry = Column(Geometry(geometry_type='GEOMETRY', srid=4326))
    properties = Column(JSON)

    def to_dict(self    ):
        return {c.name: getattr(self, c.name) for c in self.__table__.columns}

# %%
from sqlalchemy.orm import sessionmaker
from sqlalchemy import create_engine
from sqlalchemy.dialects.postgresql import insert

engine = create_engine(f"postgresql://postgres:{PASSWORD}@localhost:15432/postgres")
Session = sessionmaker(bind=engine)
session = Session()

# drop the table if it exists
Base.metadata.drop_all(engine)

# create the table if it doesn't exist
Base.metadata.create_all(engine)

# def insert_places(places: list[PlaceORM]):
#     # Get the table from your model
#     table = PlaceORM.__table__

#     # Prepare insert statement with conflict handling for PostgreSQL
#     stmt = insert(table).values([place.to_dict() for place in places])  # Assuming `to_dict()` converts ORM objects to dicts
#     stmt = stmt.on_conflict_do_update(
#         index_elements=['id'],  # Conflict on 'id'
#         set_={col.name: getattr(stmt.excluded, col.name) for col in table.columns if col.name != 'id'}
#     )

#     # Execute the statement
#     session.execute(stmt)
#     session.commit()


def insert_places(places: list[PlaceORM]):
    # Use bulk_save_objects to efficiently perform the bulk upsert
    session.bulk_save_objects(places)
    session.commit()

# %%
import duckdb
import time
from geoalchemy2.shape import from_shape
from shapely import wkb
from pprint import pprint

# Define your file paths
file1 = '../data/divisions.parquet'
file2 = '../data/division_areas.parquet'

def process_paginated_data(file1, file2, page_size=1000):
    con = duckdb.connect()

    # Function to process a chunk of data based on LIMIT and OFFSET
    def fetch_and_process_data(offset):
        query = f"""
        SELECT f1.id, f1.names, f1.subtype, f1.hierarchies, f1.country, f2.geometry
        FROM '{file1}' AS f1
        LEFT JOIN '{file2}' AS f2
        ON f1.id = f2.division_id
        ORDER BY f1.id
        LIMIT {page_size} OFFSET {offset}
        """

        # Run the query and get a DataFrame
        start_time = time.time()
        result_df = con.execute(query).df()
        end_time = time.time()
        print(f"Time taken to execute query: {end_time - start_time} seconds")

        if result_df.empty:
            return False  # No more data to process

        start_time = time.time()
        places = []
        for index, row in result_df.iterrows():
            orig_names = row.get("names")
            names = []
            if orig_names:
                primary_name = orig_names.get("primary")
                common_english_name = (orig_names.get("common") or {}).get("en")
                names = [name for name in [primary_name, common_english_name] if name]
            if len(row["hierarchies"]) > 0:
                hierarchies = row["hierarchies"][0]
                hierarchy = [h["name"] for h in hierarchies]

            geometry = from_shape(wkb.loads(bytes(row['geometry'])), srid=4326)

            place = PlaceORM(
                names=names,
                geometry=geometry,
                type=row['subtype'],
                id=row['id'],
                hierarchy=hierarchy,
                properties={
                    "country": row['country'],
                })
            places.append(place)
            # pprint(place.to_dict())
        end_time = time.time()
        print(f"Time taken to process data: {end_time - start_time} seconds")

        start_time = time.time()
        insert_places(places)
        end_time = time.time()
        print(f"Time taken to insert data: {end_time - start_time} seconds")
        return True

    # Initial offset
    offset = 0

    while True:
        # Process data in chunks
        print(f"Processing chunk {offset} - {offset + page_size}")
        if not fetch_and_process_data(offset):
            break
        offset += page_size  # Move to the next chunk

# Call the function with your files and desired page size
process_paginated_data(file1, file2, page_size=10000)
# Out:
# Processing chunk 0 - 10000
# Time taken to execute query: 3.1809241771698 seconds
# Time taken to process data: 0.8589038848876953 seconds
# Time taken to insert data: 2.394068479537964 seconds
# Processing chunk 10000 - 20000
# Time taken to execute query: 3.076491355895996 seconds
# Time taken to process data: 0.8016703128814697 seconds
# Time taken to insert data: 2.1773884296417236 seconds
# Processing chunk 20000 - 30000
# Time taken to execute query: 3.3585617542266846 seconds
# Time taken to process data: 0.8011825084686279 seconds
# Time taken to insert data: 2.2265303134918213 seconds
# Processing chunk 30000 - 40000
# Time taken to execute query: 3.3278515338897705 seconds
# Time taken to process data: 0.792792558670044 seconds
# Time taken to insert data: 2.4132275581359863 seconds
# Processing chunk 40000 - 50000
# Time taken to execute query: 3.586871385574341 seconds
# Time taken to process data: 0.8485774993896484 seconds
# Time taken to insert data: 2.5634658336639404 seconds
# Processing chunk 50000 - 60000
# Time taken to execute query: 3.571556806564331 seconds
# Time taken to process data: 0.8079953193664551 seconds
# Time taken to insert data: 2.5858936309814453 seconds
# Processing chunk 60000 - 70000
# Time taken to execute query: 3.851341962814331 seconds
# Time taken to process data: 0.7929933071136475 seconds
# Time taken to insert data: 2.4264976978302 seconds
# Processing chunk 70000 - 80000
# Time taken to execute query: 3.8145015239715576 seconds
# Time taken to process data: 0.803959846496582 seconds
# Time taken to insert data: 2.487818479537964 seconds
# Processing chunk 80000 - 90000
# Time taken to execute query: 3.903517007827759 seconds
# Time taken to process data: 0.8324427604675293 seconds
# Time taken to insert data: 2.0554561614990234 seconds
# Processing chunk 90000 - 100000
# Time taken to execute query: 4.232206106185913 seconds
# Time taken to process data: 0.8470849990844727 seconds
# Time taken to insert data: 2.3963818550109863 seconds
# Processing chunk 100000 - 110000
# Time taken to execute query: 4.409313440322876 seconds
# Time taken to process data: 0.7984676361083984 seconds
# Time taken to insert data: 2.51751446723938 seconds
# Processing chunk 110000 - 120000
# Time taken to execute query: 4.541931867599487 seconds
# Time taken to process data: 0.7776143550872803 seconds
# Time taken to insert data: 2.222808361053467 seconds
# Processing chunk 120000 - 130000
# Time taken to execute query: 4.560552358627319 seconds
# Time taken to process data: 0.8279588222503662 seconds
# Time taken to insert data: 2.094825029373169 seconds
# Processing chunk 130000 - 140000
# Time taken to execute query: 4.791810512542725 seconds
# Time taken to process data: 0.8030107021331787 seconds
# Time taken to insert data: 2.371197462081909 seconds
# Processing chunk 140000 - 150000
# Time taken to execute query: 4.616633892059326 seconds
# Time taken to process data: 0.7850158214569092 seconds
# Time taken to insert data: 1.9647634029388428 seconds
# Processing chunk 150000 - 160000
# Time taken to execute query: 4.850658893585205 seconds
# Time taken to process data: 0.7872235774993896 seconds
# Time taken to insert data: 2.2316207885742188 seconds
# Processing chunk 160000 - 170000
# Time taken to execute query: 4.671114206314087 seconds
# Time taken to process data: 0.786949634552002 seconds
# Time taken to insert data: 2.033860683441162 seconds
# Processing chunk 170000 - 180000
# Time taken to execute query: 4.997762680053711 seconds
# Time taken to process data: 0.7823197841644287 seconds
# Time taken to insert data: 2.2052245140075684 seconds
# Processing chunk 180000 - 190000
# Time taken to execute query: 5.153060436248779 seconds
# Time taken to process data: 0.760704517364502 seconds
# Time taken to insert data: 2.2223711013793945 seconds
# Processing chunk 190000 - 200000
# Time taken to execute query: 5.2590415477752686 seconds
# Time taken to process data: 0.8165721893310547 seconds
# Time taken to insert data: 2.0599849224090576 seconds
# Processing chunk 200000 - 210000
# Time taken to execute query: 5.2515528202056885 seconds
# Time taken to process data: 0.8044908046722412 seconds
# Time taken to insert data: 2.323298931121826 seconds
# Processing chunk 210000 - 220000
# Time taken to execute query: 5.667557001113892 seconds
# Time taken to process data: 0.7778980731964111 seconds
# Time taken to insert data: 2.1461451053619385 seconds
# Processing chunk 220000 - 230000
# Time taken to execute query: 5.724477767944336 seconds
# Time taken to process data: 0.7830123901367188 seconds
# Time taken to insert data: 2.1232407093048096 seconds
# Processing chunk 230000 - 240000
# Time taken to execute query: 5.173053026199341 seconds
# Time taken to process data: 0.8085086345672607 seconds
# Time taken to insert data: 2.305128574371338 seconds
# Processing chunk 240000 - 250000
# Time taken to execute query: 5.217145681381226 seconds
# Time taken to process data: 0.8409993648529053 seconds
# Time taken to insert data: 2.6007702350616455 seconds
# Processing chunk 250000 - 260000
# Time taken to execute query: 5.885865926742554 seconds
# Time taken to process data: 0.8148431777954102 seconds
# Time taken to insert data: 2.031458616256714 seconds
# Processing chunk 260000 - 270000
# Time taken to execute query: 5.30495023727417 seconds
# Time taken to process data: 0.7802314758300781 seconds
# Time taken to insert data: 1.9978086948394775 seconds
# Processing chunk 270000 - 280000
# Time taken to execute query: 6.365807056427002 seconds
# Time taken to process data: 0.7978329658508301 seconds
# Time taken to insert data: 2.234961748123169 seconds
# Processing chunk 280000 - 290000
# Time taken to execute query: 6.443854808807373 seconds
# Time taken to process data: 0.7868680953979492 seconds
# Time taken to insert data: 2.3170149326324463 seconds
# Processing chunk 290000 - 300000
# Time taken to execute query: 5.66267204284668 seconds
# Time taken to process data: 0.818744421005249 seconds
# Time taken to insert data: 2.152217388153076 seconds
# Processing chunk 300000 - 310000
# Time taken to execute query: 5.740047931671143 seconds
# Time taken to process data: 0.8074629306793213 seconds
# Time taken to insert data: 2.570214033126831 seconds
# Processing chunk 310000 - 320000
# Time taken to execute query: 6.768802165985107 seconds
# Time taken to process data: 0.84442138671875 seconds
# Time taken to insert data: 2.7510175704956055 seconds
# Processing chunk 320000 - 330000
# Time taken to execute query: 6.3347086906433105 seconds
# Time taken to process data: 0.7735631465911865 seconds
# Time taken to insert data: 2.2283267974853516 seconds
# Processing chunk 330000 - 340000
# Time taken to execute query: 6.434478282928467 seconds
# Time taken to process data: 0.7720353603363037 seconds
# Time taken to insert data: 1.9542558193206787 seconds
# Processing chunk 340000 - 350000
# Time taken to execute query: 5.8452513217926025 seconds
# Time taken to process data: 0.7788612842559814 seconds
# Time taken to insert data: 2.1434593200683594 seconds
# Processing chunk 350000 - 360000
# Time taken to execute query: 6.448046445846558 seconds
# Time taken to process data: 0.8411469459533691 seconds
# Time taken to insert data: 2.2219769954681396 seconds
# Processing chunk 360000 - 370000
# Time taken to execute query: 5.979730606079102 seconds
# Time taken to process data: 0.8154010772705078 seconds
# Time taken to insert data: 2.4126477241516113 seconds
# Processing chunk 370000 - 380000
# Time taken to execute query: 6.160752058029175 seconds
# Time taken to process data: 0.8038210868835449 seconds
# Time taken to insert data: 2.194856882095337 seconds
# Processing chunk 380000 - 390000
# Time taken to execute query: 6.255900144577026 seconds
# Time taken to process data: 0.7723987102508545 seconds
# Time taken to insert data: 1.877920150756836 seconds
# Processing chunk 390000 - 400000
# Time taken to execute query: 6.1624884605407715 seconds
# Time taken to process data: 0.8448891639709473 seconds
# Time taken to insert data: 3.2887630462646484 seconds
# Processing chunk 400000 - 410000
# Time taken to execute query: 6.655590534210205 seconds
# Time taken to process data: 0.7830536365509033 seconds
# Time taken to insert data: 2.4130725860595703 seconds
# Processing chunk 410000 - 420000
# Time taken to execute query: 7.2188708782196045 seconds
# Time taken to process data: 0.7983729839324951 seconds
# Time taken to insert data: 2.4336299896240234 seconds
# Processing chunk 420000 - 430000
# Time taken to execute query: 7.126620292663574 seconds
# Time taken to process data: 0.7855300903320312 seconds
# Time taken to insert data: 2.258918285369873 seconds
# Processing chunk 430000 - 440000
# Time taken to execute query: 7.4176084995269775 seconds
# Time taken to process data: 0.8335366249084473 seconds
# Time taken to insert data: 2.1731584072113037 seconds
# Processing chunk 440000 - 450000
# Time taken to execute query: 7.446373701095581 seconds
# Time taken to process data: 0.7593178749084473 seconds
# Time taken to insert data: 1.9814627170562744 seconds
# Processing chunk 450000 - 460000
# Time taken to execute query: 6.7093353271484375 seconds
# Time taken to process data: 0.8008036613464355 seconds
# Time taken to insert data: 2.2116920948028564 seconds
# Processing chunk 460000 - 470000
# Time taken to execute query: 7.58554220199585 seconds
# Time taken to process data: 0.7678003311157227 seconds
# Time taken to insert data: 1.9753260612487793 seconds
# Processing chunk 470000 - 480000
# Time taken to execute query: 7.625478982925415 seconds
# Time taken to process data: 0.8432567119598389 seconds
# Time taken to insert data: 2.204224109649658 seconds
# Processing chunk 480000 - 490000
# Time taken to execute query: 6.721054315567017 seconds
# Time taken to process data: 0.7767055034637451 seconds
# Time taken to insert data: 2.08417010307312 seconds
# Processing chunk 490000 - 500000
# Time taken to execute query: 7.074748992919922 seconds
# Time taken to process data: 0.7749233245849609 seconds
# Time taken to insert data: 1.7860219478607178 seconds
# Processing chunk 500000 - 510000
# Time taken to execute query: 7.2317399978637695 seconds
# Time taken to process data: 0.7966344356536865 seconds
# Time taken to insert data: 1.8696107864379883 seconds
# Processing chunk 510000 - 520000
# Time taken to execute query: 7.547298908233643 seconds
# Time taken to process data: 0.8488461971282959 seconds
# Time taken to insert data: 2.2780158519744873 seconds
# Processing chunk 520000 - 530000
# Time taken to execute query: 7.324478387832642 seconds
# Time taken to process data: 0.8083221912384033 seconds
# Time taken to insert data: 2.341874599456787 seconds
# Processing chunk 530000 - 540000
# Time taken to execute query: 7.0866968631744385 seconds
# Time taken to process data: 0.795405387878418 seconds
# Time taken to insert data: 2.3207972049713135 seconds
# Processing chunk 540000 - 550000
# Time taken to execute query: 7.1063807010650635 seconds
# Time taken to process data: 0.7930867671966553 seconds
# Time taken to insert data: 2.6441593170166016 seconds
# Processing chunk 550000 - 560000
# Time taken to execute query: 7.573667287826538 seconds
# Time taken to process data: 0.7897694110870361 seconds
# Time taken to insert data: 2.4520230293273926 seconds
# Processing chunk 560000 - 570000
# Time taken to execute query: 8.87177586555481 seconds
# Time taken to process data: 0.7686069011688232 seconds
# Time taken to insert data: 3.2534172534942627 seconds
# Processing chunk 570000 - 580000
# Time taken to execute query: 8.626292943954468 seconds
# Time taken to process data: 0.7905292510986328 seconds
# Time taken to insert data: 3.1105754375457764 seconds
# Processing chunk 580000 - 590000
# Time taken to execute query: 7.412883043289185 seconds
# Time taken to process data: 0.7852613925933838 seconds
# Time taken to insert data: 2.751063585281372 seconds
# Processing chunk 590000 - 600000
# Time taken to execute query: 7.620778560638428 seconds
# Time taken to process data: 0.8532085418701172 seconds
# Time taken to insert data: 3.0544722080230713 seconds
# Processing chunk 600000 - 610000
# Time taken to execute query: 7.784893035888672 seconds
# Time taken to process data: 0.8047235012054443 seconds
# Time taken to insert data: 2.840538501739502 seconds
# Processing chunk 610000 - 620000
# Time taken to execute query: 7.552792549133301 seconds
# Time taken to process data: 0.7556784152984619 seconds
# Time taken to insert data: 2.044093132019043 seconds
# Processing chunk 620000 - 630000
# Time taken to execute query: 7.907287359237671 seconds
# Time taken to process data: 0.783804178237915 seconds
# Time taken to insert data: 2.3623220920562744 seconds
# Processing chunk 630000 - 640000
# Time taken to execute query: 7.9093098640441895 seconds
# Time taken to process data: 0.7960374355316162 seconds
# Time taken to insert data: 3.2274086475372314 seconds
# Processing chunk 640000 - 650000
# Time taken to execute query: 7.918828725814819 seconds
# Time taken to process data: 0.8815743923187256 seconds
# Time taken to insert data: 2.5872347354888916 seconds
# Processing chunk 650000 - 660000
# Time taken to execute query: 8.234590530395508 seconds
# Time taken to process data: 0.8243708610534668 seconds
# Time taken to insert data: 2.1761739253997803 seconds
# Processing chunk 660000 - 670000
# Time taken to execute query: 7.99187159538269 seconds
# Time taken to process data: 0.8545658588409424 seconds
# Time taken to insert data: 2.9131808280944824 seconds
# Processing chunk 670000 - 680000
# Time taken to execute query: 8.17686152458191 seconds
# Time taken to process data: 0.7679929733276367 seconds
# Time taken to insert data: 1.9989013671875 seconds
# Processing chunk 680000 - 690000
# Time taken to execute query: 8.033124446868896 seconds
# Time taken to process data: 0.790189266204834 seconds
# Time taken to insert data: 2.0172948837280273 seconds
# Processing chunk 690000 - 700000
# Time taken to execute query: 7.936378240585327 seconds
# Time taken to process data: 0.7636439800262451 seconds
# Time taken to insert data: 2.0639712810516357 seconds
# Processing chunk 700000 - 710000
# Time taken to execute query: 8.352591276168823 seconds
# Time taken to process data: 0.8121564388275146 seconds
# Time taken to insert data: 2.6308746337890625 seconds
# Processing chunk 710000 - 720000
# Time taken to execute query: 8.081858396530151 seconds
# Time taken to process data: 0.7800188064575195 seconds
# Time taken to insert data: 2.1696572303771973 seconds
# Processing chunk 720000 - 730000
# Time taken to execute query: 8.262803792953491 seconds
# Time taken to process data: 0.802337646484375 seconds
# Time taken to insert data: 2.516472101211548 seconds
# Processing chunk 730000 - 740000
# Time taken to execute query: 8.123125076293945 seconds
# Time taken to process data: 0.814378023147583 seconds
# Time taken to insert data: 2.525438070297241 seconds
# Processing chunk 740000 - 750000
# Time taken to execute query: 8.251798391342163 seconds
# Time taken to process data: 0.8272712230682373 seconds
# Time taken to insert data: 2.2908382415771484 seconds
# Processing chunk 750000 - 760000
# Time taken to execute query: 9.02860403060913 seconds
# Time taken to process data: 0.8662936687469482 seconds
# Time taken to insert data: 2.366727828979492 seconds
# Processing chunk 760000 - 770000
# Time taken to execute query: 8.537076950073242 seconds
# Time taken to process data: 0.8001482486724854 seconds
# Time taken to insert data: 2.351811170578003 seconds
# Processing chunk 770000 - 780000
# Time taken to execute query: 8.56234335899353 seconds
# Time taken to process data: 0.8279976844787598 seconds
# Time taken to insert data: 2.5924324989318848 seconds
# Processing chunk 780000 - 790000
# Time taken to execute query: 8.620075225830078 seconds
# Time taken to process data: 0.8555045127868652 seconds
# Time taken to insert data: 2.483858108520508 seconds
# Processing chunk 790000 - 800000
# Time taken to execute query: 8.775789976119995 seconds
# Time taken to process data: 0.7794370651245117 seconds
# Time taken to insert data: 2.1380529403686523 seconds
# Processing chunk 800000 - 810000
# Time taken to execute query: 8.619517803192139 seconds
# Time taken to process data: 0.7785553932189941 seconds
# Time taken to insert data: 2.2684693336486816 seconds
# Processing chunk 810000 - 820000
# Time taken to execute query: 8.402399778366089 seconds
# Time taken to process data: 0.8000814914703369 seconds
# Time taken to insert data: 2.1419849395751953 seconds
# Processing chunk 820000 - 830000
# Time taken to execute query: 8.741018772125244 seconds
# Time taken to process data: 0.7848286628723145 seconds
# Time taken to insert data: 1.9323832988739014 seconds
# Processing chunk 830000 - 840000
# Time taken to execute query: 8.515278577804565 seconds
# Time taken to process data: 0.756417989730835 seconds
# Time taken to insert data: 1.97402024269104 seconds
# Processing chunk 840000 - 850000
# Time taken to execute query: 9.040554523468018 seconds
# Time taken to process data: 0.7785651683807373 seconds
# Time taken to insert data: 2.1322929859161377 seconds
# Processing chunk 850000 - 860000
# Time taken to execute query: 9.04557991027832 seconds
# Time taken to process data: 0.7767200469970703 seconds
# Time taken to insert data: 2.0797107219696045 seconds
# Processing chunk 860000 - 870000
# Time taken to execute query: 9.83635425567627 seconds
# Time taken to process data: 0.7886135578155518 seconds
# Time taken to insert data: 1.7252984046936035 seconds
# Processing chunk 870000 - 880000
# Time taken to execute query: 9.14788269996643 seconds
# Time taken to process data: 0.7762441635131836 seconds
# Time taken to insert data: 2.117513656616211 seconds
# Processing chunk 880000 - 890000
# Time taken to execute query: 9.051327466964722 seconds
# Time taken to process data: 0.7845029830932617 seconds
# Time taken to insert data: 2.370439291000366 seconds
# Processing chunk 890000 - 900000
# Time taken to execute query: 9.176064491271973 seconds
# Time taken to process data: 0.8449432849884033 seconds
# Time taken to insert data: 1.9912030696868896 seconds
# Processing chunk 900000 - 910000
# Time taken to execute query: 9.126654863357544 seconds
# Time taken to process data: 0.826873779296875 seconds
# Time taken to insert data: 2.1724231243133545 seconds
# Processing chunk 910000 - 920000
# Time taken to execute query: 9.559790849685669 seconds
# Time taken to process data: 0.8039004802703857 seconds
# Time taken to insert data: 2.388606071472168 seconds
# Processing chunk 920000 - 930000
# Time taken to execute query: 9.460642337799072 seconds
# Time taken to process data: 0.7943816184997559 seconds
# Time taken to insert data: 2.696376085281372 seconds
# Processing chunk 930000 - 940000
# Time taken to execute query: 9.219433546066284 seconds
# Time taken to process data: 0.7774107456207275 seconds
# Time taken to insert data: 1.9740595817565918 seconds
# Processing chunk 940000 - 950000
# Time taken to execute query: 9.281070470809937 seconds
# Time taken to process data: 0.8273677825927734 seconds
# Time taken to insert data: 2.236140012741089 seconds
# Processing chunk 950000 - 960000
# Time taken to execute query: 9.40756106376648 seconds
# Time taken to process data: 0.772165060043335 seconds
# Time taken to insert data: 1.872089147567749 seconds
# Processing chunk 960000 - 970000
# Time taken to execute query: 9.474193096160889 seconds
# Time taken to process data: 0.8024125099182129 seconds
# Time taken to insert data: 2.334670305252075 seconds
# Processing chunk 970000 - 980000
# Time taken to execute query: 9.570493698120117 seconds
# Time taken to process data: 0.7947862148284912 seconds
# Time taken to insert data: 2.32218074798584 seconds
# Processing chunk 980000 - 990000
# Time taken to execute query: 9.85981297492981 seconds
# Time taken to process data: 0.8270297050476074 seconds
# Time taken to insert data: 2.4311485290527344 seconds
# Processing chunk 990000 - 1000000
# Time taken to execute query: 9.682856798171997 seconds
# Time taken to process data: 0.7851700782775879 seconds
# Time taken to insert data: 2.2324941158294678 seconds
# Processing chunk 1000000 - 1010000
# Time taken to execute query: 9.762448787689209 seconds
# Time taken to process data: 0.7910423278808594 seconds
# Time taken to insert data: 2.550067186355591 seconds
# Processing chunk 1010000 - 1020000
# Time taken to execute query: 9.611151933670044 seconds
# Time taken to process data: 0.8012542724609375 seconds
# Time taken to insert data: 2.273268938064575 seconds
# Processing chunk 1020000 - 1030000
# Time taken to execute query: 9.969388723373413 seconds
# Time taken to process data: 0.8143727779388428 seconds
# Time taken to insert data: 2.0969443321228027 seconds
# Processing chunk 1030000 - 1040000
# Time taken to execute query: 10.782450437545776 seconds
# Time taken to process data: 0.801306962966919 seconds
# Time taken to insert data: 2.2183191776275635 seconds
# Processing chunk 1040000 - 1050000
# Time taken to execute query: 10.149307489395142 seconds
# Time taken to process data: 0.8167381286621094 seconds
# Time taken to insert data: 2.555537462234497 seconds
# Processing chunk 1050000 - 1060000
# Time taken to execute query: 10.22289752960205 seconds
# Time taken to process data: 0.8343019485473633 seconds
# Time taken to insert data: 2.456472396850586 seconds
# Processing chunk 1060000 - 1070000
# Time taken to execute query: 10.120209455490112 seconds
# Time taken to process data: 0.8189277648925781 seconds
# Time taken to insert data: 2.5330679416656494 seconds
# Processing chunk 1070000 - 1080000
# Time taken to execute query: 10.867612361907959 seconds
# Time taken to process data: 0.8008005619049072 seconds
# Time taken to insert data: 2.4829065799713135 seconds
# Processing chunk 1080000 - 1090000
# Time taken to execute query: 10.066097497940063 seconds
# Time taken to process data: 0.7887060642242432 seconds
# Time taken to insert data: 2.1804304122924805 seconds
# Processing chunk 1090000 - 1100000
# Time taken to execute query: 10.273497104644775 seconds
# Time taken to process data: 0.7949094772338867 seconds
# Time taken to insert data: 2.237800121307373 seconds
# Processing chunk 1100000 - 1110000
# Time taken to execute query: 10.737834453582764 seconds
# Time taken to process data: 0.8183450698852539 seconds
# Time taken to insert data: 2.07505202293396 seconds
# Processing chunk 1110000 - 1120000
# Time taken to execute query: 10.166686296463013 seconds
# Time taken to process data: 0.7825064659118652 seconds
# Time taken to insert data: 2.278140068054199 seconds
# Processing chunk 1120000 - 1130000
# Time taken to execute query: 10.444525241851807 seconds
# Time taken to process data: 0.7731730937957764 seconds
# Time taken to insert data: 2.3339524269104004 seconds
# Processing chunk 1130000 - 1140000
# Time taken to execute query: 10.843980312347412 seconds
# Time taken to process data: 0.8411390781402588 seconds
# Time taken to insert data: 2.252505302429199 seconds
# Processing chunk 1140000 - 1150000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 83
#      80         offset += page_size  # Move to the next chunk
#      82 # Call the function with your files and desired page size
# ---> 83 process_paginated_data(file1, file2, page_size=10000)
#
# Cell In[6], line 78, in process_paginated_data(file1, file2, page_size)
#      75 while True:
#      76     # Process data in chunks
#      77     print(f"Processing chunk {offset} - {offset + page_size}")
# ---> 78     if not fetch_and_process_data(offset):
#      79         break
#      80     offset += page_size
#
# Cell In[6], line 27, in process_paginated_data.<locals>.fetch_and_process_data(offset)
#      25 # Run the query and get a DataFrame
#      26 start_time = time.time()
# ---> 27 result_df = con.execute(query).df()
#      28 end_time = time.time()
#      29 print(f"Time taken to execute query: {end_time - start_time} seconds")
#
# RuntimeError: Query interrupted

# %%
# show one place and its geometry as geojson

from sqlalchemy import select, func

stmt = select(
    PlaceORM.id,
    PlaceORM.names,
    func.ST_AsGeoJSON(PlaceORM.geometry).label("geometry_json")
).limit(1)

results = session.execute(stmt).all()

pprint(results)

# save as geojson

with open("places.geojson", "w") as f:
    f.write(results[0].geometry_json)
# Out:
# [('085000003fffffff0126c753d6cd5249', ['La Gaile'], None)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 18
#      15 # save as geojson
#      17 with open("places.geojson", "w") as f:
# ---> 18     f.write(results[0].geometry_json)
#
# TypeError: write() argument must be str, not None

# %%
session.commit()

# %%
query = "New York"

# search for the query in the database

results = session.execute(select(PlaceORM).where(PlaceORM.names.any(query))).all()

pprint([result[0].to_dict() for result in results])
# Out:
# [{'geometry': None,
#   'hierarchy': ['United States', 'Missouri', 'Caldwell County', 'New York'],
#   'id': '0850c31cffffffff012426d7a157b4aa',
#   'names': ['New York'],
#   'properties': {'country': 'US'},
#   'type': 'locality'},
#  {'geometry': None,
#   'hierarchy': ['Sierra Leone',
#                 'Western Area',
#                 'Western Area Rural',
#                 'New York'],
#   'id': '08514493bfffffff01deb75ea9daa7f0',
#   'names': ['New York'],
#   'properties': {'country': 'SL'},
#   'type': 'neighborhood'},
#  {'geometry': None,
#   'hierarchy': ['United States', 'Texas', 'Henderson County', 'New York'],
#   'id': '0852ab47bfffffff01bb8c3ae3deb03e',
#   'names': ['New York'],
#   'properties': {'country': 'US'},
#   'type': 'locality'},
#  {'geometry': None,
#   'hierarchy': ['Colombia', 'Guaviare', 'El Retorno', 'New York'],
#   'id': '085196583fffffff0109b8c0db78b88c',
#   'names': ['New York'],
#   'properties': {'country': 'CO'},
#   'type': 'locality'},
#  {'geometry': None,
#   'hierarchy': ['Sierra Leone', 'Southern Province', 'Bo District', 'New York'],
#   'id': '08503ad97fffffff013aad26b0470563',
#   'names': ['New York'],
#   'properties': {'country': 'SL'},
#   'type': 'macrohood'}]
